# %% [markdown]
# Importamos pandas

# %% [markdown]
# # Operaciones df sobre Titanic dataset

# %%
# Cargamos el dataset desde la url: https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv

# %%
# Muestra la cabecera
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Muestra la cola
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# Cuantas filas y columnas componnen nuestro dataset?
# Out:
# (891, 12)

# %%
# Obten un summary del df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
# Tipo de datos contenidos en las columnas
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Resumen estadístico de las columnas numéricas
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Cuantos valores vacíos tenemos en cada columna?
# Out:
# Missing values count:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Cuenta el úmero de pasajeros de cada clase sin usar groupby
# Out:
# Passenger Count by Class:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# Calcula la edad media por sexo
# Out:
# Mean Age by Sex:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
# Muesta el precio promedio pagado por cada clase
# Out:
# Precio promedio por cada clase:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
# Muesta el precio promedio pagado por cada clase y sexo
# Out:
# Precio promedio por cada clase y sexo:
# Pclass  Sex
# 1       female    106.125798
#         male       67.226127
# 2       female     21.970121
#         male       19.741782
# 3       female     16.118810
#         male       12.661633
# Name: Fare, dtype: float64

# %%
# Muesta el número de hombres y mujeres que embarcaron en cada puerto (usando groupby)
# Out:
# Número de hombre y mujeres embarcados en cada puerto:
# Pclass  Sex
# 1       female    106.125798
#         male       67.226127
# 2       female     21.970121
#         male       19.741782
# 3       female     16.118810
#         male       12.661633
# Name: Fare, dtype: float64

# %%
# Ordena el df por edad de manera ascendente
# Out:
# Dataset sorted by age (ascending):
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 831          832         1       2  Richards, Master. George Sibley    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 827          828         1       2            Mallet, Master. Andre    male
# 381          382         1       3      Nakid, Miss. Maria ("Mary")  female
# 164          165         0       3     Panula, Master. Eino Viljami    male
#
#       Age  SibSp  Parch           Ticket      Fare    Cabin Embarked
# ...

# %%
# Filtra el dataframe de modo que se muestren solo los pasajeros que embarcaron en el puerto C y Q
# Out:
#      PassengerId  Survived  Pclass  \
# 803          804         1       3
# 644          645         1       3
# 469          470         1       3
# 827          828         1       2
# 381          382         1       3
# ..           ...       ...     ...
# 828          829         1       3
# 832          833         0       3
# 839          840         1       1
# 849          850         1       1
# 859          860         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 803               Thomas, Master. Assad Alexander    male  0.42      0      1
# 644                        Baclini, Miss. Eugenie  female  0.75      2      1
# 469                 Baclini, Miss. Helene Barbara  female  0.75      2      1
# 827                         Mallet, Master. Andre    male  1.00      0      2
# 381                   Nakid, Miss. Maria ("Mary")  female  1.00      0      2
# ...

# %%
# Filtra el dataframe de modo que se muestren las personas cuyo pasaje era menor que el precio medio de los pasajes
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 839          840         1       1                      Marechal, Mr. Pierre
# 859          860         0       3                          Razi, Mr. Raihed
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# Filtra el dataframe de modo que se muestren las personas cuyo pasage era menor que el precio medio de los pasages y además eran de primera clase
# Out:
#      PassengerId  Survived  Pclass  \
# 136          137         1       1
# 887          888         1       1
# 889          890         1       1
# 607          608         1       1
# 430          431         1       1
# 782          783         0       1
# 452          453         0       1
# 842          843         1       1
# 632          633         1       1
# 872          873         0       1
# 447          448         1       1
# 604          605         1       1
# 701          702         1       1
# 572          573         1       1
# 512          513         1       1
# 273          274         0       1
# 822          823         0       1
# 806          807         0       1
# 30            31         0       1
# 209          210         1       1
# 263          264         0       1
# 707          708         1       1
# 194          195         1       1
# 536          537         0       1
# 187          188         1       1
# ...

# %%
# Filtra y muestra el nombre del pasajero cuyo pasage era igual al valor mínimo y además sobrevivió (Un pasajero con suerte)
# Out:
# 271    Tornquist, Mr. William Henry
# Name: Name, dtype: object

# %%
# Elimina las columnas que creas que no son necesarias para predecir la supervivencia de una persona

# %%
# Elimina los registros que contengan valores vacíos y almacenalos en una variable llamada df_clean

# %%
# Comprueba que efectivamente dejamos de tener valores vacíos
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# dtype: int64

# %%
# Resetea los indices del dataframe sin que se incluya una columna index
# Out:
#      Survived  Pclass     Sex    Age  SibSp  Parch
# 0           1       3    male   0.42      0      1
# 1           1       2    male   0.67      1      1
# 2           1       3  female   0.75      2      1
# 3           1       3  female   0.75      2      1
# 4           1       2    male   0.83      0      2
# ..        ...     ...     ...    ...    ...    ...
# 709         0       3    male  70.50      0      0
# 710         0       1    male  71.00      0      0
# 711         0       1    male  71.00      0      0
# 712         0       3    male  74.00      0      0
# 713         1       1    male  80.00      0      0
#
# [714 rows x 6 columns]

# %%
# Exporta el df final como un archivo csv sin indices
