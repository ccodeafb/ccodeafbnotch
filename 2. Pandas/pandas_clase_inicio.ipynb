# %%
import pandas as pd

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
tupla = [("Pablo", "profesor", 28, ["pintar","musica"]),
    ("Adri", "alumno", 25, ["correr","series"]),
    ("Beni", "alumno", 60, ["senderismo","padel"]),
    ("Enrique", "alumno", 24, ["gym","correr","navegacion"]),
    ("Jose", "alumno", 41, ["mma","senderismo", "series"]),
    ("Oscar", "alumno", 24, ["gym","padel"])]

columnas = ("nombre", "rol", "edad", "aficiones")

# %%
df = pd.DataFrame(tupla, columns=columnas)

# %%
df
# Out:
#     nombre       rol  edad                  aficiones
# 0    Pablo  profesor    28           [pintar, musica]
# 1     Adri    alumno    25           [correr, series]
# 2     Beni    alumno    60        [senderismo, padel]
# 3  Enrique    alumno    24  [gym, correr, navegacion]
# 4     Jose    alumno    41  [mma, senderismo, series]
# 5    Oscar    alumno    24               [gym, padel]

# %%
# NaN = Not a Number
# CSV = Comma Separated Value

# %%
df_pelis = pd.read_csv("C:\\Users\\Usuario\\Desktop\\Code\\PelisU2.csv")

# %%
df_pelis
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#tail=mostrar los del principio, subtle= los de abajo, head= algunos aleatorios, info= info de las columnas que tiene el archivo

# %%
df_pelis.describe().T
# Out:
#                      count           mean            std     min       25%  \
# Rank                1000.0     500.500000     288.819436     1.0    250.75
# Year                1000.0    2012.783000       3.205962  2006.0   2010.00
# Runtime (Minutes)   1000.0     113.172000      18.810908    66.0    100.00
# Rating              1000.0       6.723200       0.945429     1.9      6.20
# Votes               1000.0  169808.255000  188762.647518    61.0  36309.00
# Revenue (Millions)   872.0      82.956376     103.253540     0.0     13.27
# Metascore            936.0      58.985043      17.194757    11.0     47.00
#
#                            50%         75%         max
# Rank                   500.500     750.250     1000.00
# Year                  2014.000    2016.000     2016.00
# Runtime (Minutes)      111.000     123.000      191.00
# Rating                   6.800       7.400        9.00
# Votes               110799.000  239909.750  1791916.00
# ...

# %%
#Acceder a una columna:
df_pelis.Rating
# Out:
# 0      8.1
# 1      7.0
# 2      7.3
# 3      7.2
# 4      6.2
#       ...
# 995    6.2
# 996    5.5
# 997    6.2
# 998    5.6
# 999    5.3
# Name: Rating, Length: 1000, dtype: float64

# %%
print(type(df_pelis.Rating)) #Tipo de una columna
# Out:
# <class 'pandas.core.series.Series'>

# %%
df_pelis.Rating.mean()
# Out:
# 6.723199999999999

# %%
df_pelis[df_pelis.Year <= 2007]  #muestra las filas que cumplen la condicion
# Out:
#      Rank                                       Title  \
# 39     40                                   5- 25- 77
# 64     65                                The Prestige
# 75     76    Pirates of the Caribbean: At World's End
# 78     79  Pirates of the Caribbean: Dead Man's Chest
# 99    100                                The Departed
# ..    ...                                         ...
# 965   966                               Inland Empire
# 971   972                                   Disturbia
# 982   983                         Across the Universe
# 991   992                            Taare Zameen Par
# 996   997                             Hostel: Part II
#
#                         Genre  \
# 39               Comedy,Drama
# 64       Drama,Mystery,Sci-Fi
# 75   Action,Adventure,Fantasy
# 78   Action,Adventure,Fantasy
# 99       Crime,Drama,Thriller
# ..                        ...
# 965    Drama,Mystery,Thriller
# 971    Drama,Mystery,Thriller
# 982     Drama,Fantasy,Musical
# ...

# %%
len(df_pelis[df_pelis.Year <= 2007])
# Out:
# 97

# %%
df_pelis[df_pelis.Year <= 2007].shape
# Out:
# (97, 12)

# %%
df_pelis[(df_pelis.Year >= 2010) & (df_pelis.Rating >= 8)]
# Out:
#      Rank                                         Title  \
# 0       1                       Guardians of the Galaxy
# 6       7                                    La La Land
# 16     17                                 Hacksaw Ridge
# 18     19                                          Lion
# 19     20                                       Arrival
# 26     27                       Bahubali: The Beginning
# 33     34                                      Deadpool
# 36     37                                  Interstellar
# 50     51    Star Wars: Episode VII - The Force Awakens
# 67     68                            Mad Max: Fury Road
# 74     75                                      Zootopia
# 76     77                                  The Avengers
# 80     81                                     Inception
# 82     83                       The Wolf of Wall Street
# 83     84                                     Gone Girl
# 90     91                                     Prisoners
# ...

# %%
df_pelis[(df_pelis.Year >= 2010) & (df_pelis.Rating > 8)].shape
# Out:
# (42, 12)

# %%
len(df_pelis.Director.unique()) #cuantos directores hay
# Out:
# 644

# %%
#isin()   - se usa esto porque sino no compararia cada elemento de la lista directores en la columna del dataframe, compararia la lista entera y nunca la encontraria

# %%
directores = ["Christopher Nolan", "Tim Burton"]
df_pelis[df_pelis.Director.isin(directores)]
# Out:
#      Rank                                           Title  \
# 36     37                                    Interstellar
# 54     55                                 The Dark Knight
# 64     65                                    The Prestige
# 80     81                                       Inception
# 120   121     Miss Peregrine's Home for Peculiar Children
# 124   125                           The Dark Knight Rises
# 547   548                             Alice in Wonderland
# 650   651  Sweeney Todd: The Demon Barber of Fleet Street
# 725   726                                    Dark Shadows
#
#                         Genre  \
# 36     Adventure,Drama,Sci-Fi
# 54         Action,Crime,Drama
# 64       Drama,Mystery,Sci-Fi
# 80    Action,Adventure,Sci-Fi
# 120    Adventure,Drama,Family
# 124           Action,Thriller
# 547  Adventure,Family,Fantasy
# 650      Drama,Horror,Musical
# 725     Comedy,Fantasy,Horror
#
# ...

# %%
#indices

# %%
df_pelis.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_pelis.set_index("Title")   # se cambia la columna que se considera indice
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
df_pelis.iloc[:3]
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# ...

# %%
df_pelis.iloc[-3:]
# Out:
#      Rank                   Title                  Genre  \
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...  2008
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 997                 98     6.2  70699               58.01       50.0
# ...

# %%
#en el loc se fija en el index establecido, no en la posicion

# %%
df_indice = df_pelis.set_index("Title")
df_indice.loc["Split"]
# Out:
# Rank                                                                  3
# Genre                                                   Horror,Thriller
# Description           Three girls are kidnapped by a man with a diag...
# Director                                             M. Night Shyamalan
# Actors                James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Year                                                               2016
# Runtime (Minutes)                                                   117
# Rating                                                              7.3
# Revenue (Millions)                                               138.12
# Metascore                                                          62.0
# Name: Split, dtype: object

# %%
#inplace

# %%
#drop = eliminar columnas. para ello hay que especificar a que nos referimos en el argumento, para eso sirve axis, axis=0 es fila, axis=1 es columna, por tanto, axis=1, columna Value
#df_2 = df_pelis.drop("Votes", axis=1)
#los cambios que hemos hecho no se guardan, hay que hacerlos en una variable o con inplace:
#df_pelis.drop("Votes", axis=1, inplace=True)

# %%
df_pelis
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...
