# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Resumen Algebra

# %% [markdown]
# Transfomracion lineal: $Ax$

# %%
matriz = np.random.random((2, 2))
vector = np.random.random((2, 1))

# %%
matriz
# Out:
# array([[0.47919058, 0.38403739],
#        [0.45810027, 0.47455908]])

# %%
vector
# Out:
# array([[0.41654827],
#        [0.96275278]])

# %% [markdown]
# ¿Como se aplica la transformacion lineal?

# %%
matriz@vector
# Out:
# array([[0.56933907],
#        [0.64770394]])

# %%
matriz*vector
# Out:
# array([[0.19960601, 0.15997011],
#        [0.4410373 , 0.45688307]])

# %% [markdown]
# Transformaciones a espacios de otra dimension $f:R^2 \rightarrow R^3$
#
# Para multiplicar matrices se tiene que cumplir que:
#
# $(m \times n)(n \times l) = m \times l$
#
# $n$: espacio de entrada
#
# $m$: espacio de salida
#
# $l$: cantidad de vectores a transformar
#
# Las matrices que proyectan de $f:R^n \rightarrow R^m$, tendran una dimension de $(m \times n)$

# %% [markdown]
# Ultimo ejemplo:
#
# - Crear una colecion de 100 vectores aleatorios en $R^{64}$
# - Crear una matriz que proyecte vectores de $R^{64} \rightarrow R^{128}$ y proyectarlos
# - Crear una matriz que proyecte vectores de $R^{128} \rightarrow R^{2}$ y proyectarlos
# - Hacer un plot de los puntos resultantes

# %%
x = np.random.random((64, 100))
x.shape
# Out:
# (64, 100)

# %%
A = np.random.random((128, 64))
x_128 = A@x # proyeccion en R128

# %%
x_128.shape
# Out:
# (128, 100)

# %%
plt.scatter(x_128[0, :],
            x_128[31, :])

# %%
B = np.random.random((2, 128))
x_2 = B@x_128  # proyeccion en R64

# %%
x_2.shape
# Out:
# (2, 100)

# %%
plt.scatter(x_2[0, :],
            x_2[1, :])
