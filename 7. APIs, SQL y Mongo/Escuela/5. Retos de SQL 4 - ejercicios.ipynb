# %% [markdown]
# # Retos de SQL 4
#
# **Todos los retos hay que hacerlos en Workbench y en Python con sentencias preparadas.**

# %%
import pymysql
miConexion = pymysql.connect( host='localhost', user= 'root', password='administrador', db='escuela')

# %%
try:
    cur = miConexion.cursor()
    sql = "SET sql_mode='STRICT_TRANS_TABLES,NO_ZERO_IN_DATE,NO_ZERO_DATE,ERROR_FOR_DIVISION_BY_ZERO,NO_ENGINE_SUBSTITUTION';"
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ## Reto 1
# * Obtén  los  nombres  y  apellidos  de  los  alumnos  y  los  nombres  de  las  asignaturas  en  las que  están  apuntados.

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT first_name, last_name, title FROM marks AS m INNER JOIN students AS s ON (s.idstudents = m.FK_student_mark) INNER JOIN subjects AS j ON (m.FK_subject_mark = j.idsubjects)"
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Reto 2
# * Obtén  todos  los  nombres  y  apellidos  de  los  profesores  y  los  nombres  de  las  asignaturas que  imparten.

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT first_name, last_name, title FROM subject_teacher AS m RIGHT JOIN teachers AS s ON (s.idteachers = m.FK_teachers) LEFT JOIN subjects AS j ON (m.FK_subject = j.idsubjects)"
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Reto 3
# * Obtén  el  número total de alumnos por asignatura, el  nombre  de  la asignatura  y  el  nombre y apellidos  del profesor  que  la  imparte.
#
# * **NOTA:** Para que no aparezcan notas repetidas solo debe haber un profesor por asignatura y un grupo por asignatura y profesor

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT title, COUNT(FK_student_mark), first_name, last_name FROM subjects AS m INNER JOIN  marks AS s ON (m.idsubjects = s.FK_subject_mark) INNER JOIN subject_teacher AS j ON (m.idsubjects = j.FK_subject)  INNER JOIN teachers AS t ON (t.idteachers = j.FK_teachers) GROUP BY idsubjects"
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# '       '

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Reto 4
# * Obtén  el  nombre  y  apellido  de  todos  los  profesores,  la  asignatura que  imparten  y la  nota media de la  asignatura que  imparten.

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT title, avg(mark), first_name, last_name FROM subjects AS m INNER JOIN  marks AS s ON (m.idsubjects = s.FK_subject_mark) INNER JOIN subject_teacher AS j ON (m.idsubjects = j.FK_subject)  RIGHT JOIN teachers AS t ON (t.idteachers = j.FK_teachers) GROUP BY idsubjects"
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Reto 5
# * Al  finalizar  el  curso, queremos  hacer  un  reporte  completo  de los  alumnos  del  bootcamp para  poder  mejorar  en  el  futuro.
# * Para  ello  se  pide  listar  el  nombre  y  apellidos  del  alumno,  el  número de  asignaturas  que  ha  cursado,  la  nota  media  de  todas  ellas,  la  nota más alta y la nota más baja conseguida.

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT first_name, last_name, count(idsubjects), avg(mark), max(mark), min(mark) FROM marks AS m INNER JOIN students AS s ON (s.idstudents = m.FK_student_mark) INNER JOIN subjects AS j ON (m.FK_subject_mark = j.idsubjects) GROUP BY first_name"
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Proyecto del Museo
#
# * Se quiere construir un sistema de base de datos para almacenar las piezas de un museo.
#
# * Se sabe que el museo dispone de colecciones, compuestas por piezas, que expone de manera permanente, otras colecciones que están almacenadas y por último otras que están en exposiciones itinerantes.
#
# * Las piezas de estas colecciones tienen que ser identificadas de manera única, tener un nombre, descripción, año, autor (suponemos que una pieza solo tiene un autor), y pueden estar expuestas en cualquiera de los formatos anteriormente mencionados.
#
# * Además, las piezas pueden estar en posesión, en préstamo de otros museos o prestadas a otros museos. Para estos últimos dos casos, es importante saber la fecha de préstamo y de devolución a su dueño.
#
# * Por ello no hay que olvidar llevar un registro de los datos de estos dueños de las piezas con nombres, apellidos, emails, direcciones y demás datos de importancia.
#
# * Por otro lado, el museo cuenta con un amplio abanico de expositores y vitrinas donde están expuestas las diferentes piezas de las colecciones o, en el caso de estar almacenadas, armarios y estanterías que las recogen. Para cada pieza es importante saber en qué lugar se encuentra en cada momento.
#
# * El museo, de la misma manera que expone todas las piezas, quiere también exponer con la misma importancia la vida de sus autores, por lo que es importante almacenar todos los datos de estos y asociarlos a las piezas en cuestión.
#
# * Se pide construir este sistema de base de datos, con todas las tablas y campos necesarios para albergar la información previamente descrita, guardando una coherencia y cohesión necesarias para todos los datos.  Construir el sistema con Workbench.
#
# * Además, una vez construido, se piden las siguientes consultas:
#
#    - Obtener un listado de todos los objetos que el museo tiene en préstamo, su localización dentro de la exposición, la fecha de expiración de este, la información básica (nombre, apellidos y email) de la persona que los ha prestado.
#
#    - Obtener de forma ordenada de mayor a menor, el número total de objetos o piezas agrupados por su situación dentro de la organización, esto es, cuántos hay expuestos, cuántos en  itinerancia y cuántos almacenados.
#
# * Las consultas se deben realizar en Workbench y en Python con sentencias preparadas.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
miConexion = pymysql.connect( host='localhost', user= 'root', password='administrador', db='museo')

# %% [markdown]
# - Obtener un listado de todos los objetos que el museo tiene en préstamo, su localización dentro de la exposición, la fecha de expiración de este, la información básica (nombre, apellidos y email) de la persona que los ha prestado.

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT nombre_pieza, sala, fecha_devolucion, nombre_dueño, apellido_dueño, email_dueño FROM piezas AS p INNER JOIN prestacion AS s ON (s.id_pieza_prestacion = p.idobras) INNER JOIN dueños AS d ON (d.iddueños = s.id_dueño_prestacion) INNER JOIN exp_almacen AS e ON (p.idobras = e.id_pieza_almacen)"
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Obtener de forma ordenada de mayor a menor, el número total de objetos o piezas agrupados por su situación dentro de la organización, esto es, cuántos hay expuestos, cuántos en  itinerancia y cuántos almacenados.

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT count(idobras) AS total_piezas, situacion FROM colecciones AS c JOIN piezas AS p ON (c.idcolecciones = p.id_coleccion_pieza) GROUP BY  situacion ORDER BY total_piezas DESC"
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)
