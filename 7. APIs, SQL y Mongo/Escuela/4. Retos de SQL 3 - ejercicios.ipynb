# %% [markdown]
# # Retos de SQL 3

# %%
import pymysql
miConexion = pymysql.connect( host='localhost', user= 'root', password='administrador', db='escuela')

# %% [markdown]
# ## Reto 1
#
#     * El desarrollo de estas consultas se tiene que hacer tanto en Workbench como en Python
#
# * Usando  el  ejemplo  de  base  de  datos  que  tenemos  ya  implementado  desde  unidades anteriores, calcular  la  nota media de los  alumnos  de la asignatura 1.

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT AVG(mark) FROM marks WHERE FK_subject_mark = 1"
    cur.execute(sql)
    miConexion.commit()   
    
    
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Calcular  el número  total  de alumnos  que hay en el bootcamp.

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT COUNT(*) FROM students"
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Listar  todos  los  campos  de la tabla  “groups”.

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT * FROM escuela.school_groups"
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# * Elimina  todas  las  notas  de  la  base  de  datos  que  estén  por  encima  de  5  y  que  sean  del  año pasado  (no  utilices BETWEEN).

# %%
try:
    cur = miConexion.cursor()
    sql = "DELETE mark FROM marks WHERE date LIKE '2022%' AND mark > 5"
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# * Obtén  los  datos  de  todos  los estudiantes  que  estén  en  el  bootcamp  este  año. Para ello la tabla de estudiantes debe tener un campo que sea el año de ingreso.

# %%
try:
    cur = miConexion.cursor()
    sql = "ALTER TABLE students ADD fecha_ingreso date"
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT * FROM students WHERE fecha_ingreso LIKE '2023%'"
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Calcular  el número  de profesores que hay por  cada asignatura.

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT FK_subject, COUNT(FK_teachers) FROM subject_teacher GROUP BY FK_subject "
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Reto 2
#
#     * El desarrollo de estas consultas se tiene que hacer tanto en Workbench como en Python
#
# * Obtén  el  id  y  la  nota  de  los  alumnos  que  tengan  un  id  entre  1  y 20,  o  que  tenga una nota mayor  de 8 y la nota tenga fecha del año pasado.

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT FK_student_mark, AVG (mark) FROM marks WHERE FK_student_mark BETWEEN '1' OR '20' GROUP BY FK_student_mark HAVING AVG (mark) > 8"  
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT FK_student_mark, mark FROM marks WHERE FK_student_mark BETWEEN '1' OR '20' AND mark > 8"  
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Obtén la  media de las notas que se han  dado en el último  año por asignatura.

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT idmarks, AVG(mark) FROM marks WHERE date LIKE '2023%' GROUP BY idmarks"      
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Obtén  la  media  aritmética de las notas que se han  dado en el último  año  por  alumno.

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT FK_student_mark, AVG(mark) FROM marks WHERE date LIKE '2023%' GROUP BY FK_student_mark"  
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Reto 3
# * Acceder a:
#
# https://docs.data.world/documentation/sql/reference/statistical_aggregations.html
#
# https://docs.data.world/documentation/sql/reference/other_aggregations.html
#
# Comprobar el funcionamiento de las agregaciones vistas en la teoría.

# %%
from sqlalchemy import create_engine 
miConexion = pymysql.connect( host='localhost', user= 'root', password = "administrador", db='airbnb_madrid' )

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT variance(number_of_reviews) FROM alojamientos"  
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT stddev(minimum_nights) FROM alojamientos"  
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT std(number_of_reviews) FROM alojamientos"  
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %%
try:
    cur = miConexion.cursor()
    sql = "SELECT max(price) FROM alojamientos"  
    cur.execute(sql)
    miConexion.commit()   
        
except Exception as e:
    print("Exception occured:{}".format(e))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Retos Opcionales
#
# ## Reto 1
# * Obtén  los nombres de los alumnos y  la  cantidad  total  de  asignaturas por alumno que sean Python o MySQL   y  cuyo profesor sea Jose.
#
# * **ACLARACIÓN:** El acceso a las asignaturas y a los profesores será a través de su id. Relizar el reto en python.

# %% [markdown]
# ## Reto 2
# * Obtén  los nombres de los alumnos y  la  cantidad  total  de  asignaturas por alumno que sean Python o MySQL   y  cuyo profesor sea Jose o  algún compañero que elijáis.
#
# * **ACLARACIÓN:** El acceso a las asignaturas y a los profesores será a través de su nombre.
#
#
# * El desarrollo de estas consultas se tiene que hacer tanto en Workbench como en Python
