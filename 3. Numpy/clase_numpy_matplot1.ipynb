# %%
# en numpy::: ejes = nº arrays = dimension = shape()

# %%
import numpy as np

# %%
array1 = np.array([[1],[2],[3],[4]])
array1
# Out:
# array([[1],
#        [2],
#        [3],
#        [4]])

# %%
array12 = np.array([1,2,3,4])
array12
# Out:
# array([1, 2, 3, 4])

# %%
array1.shape
# Out:
# (4, 1)

# %%
array12.shape
# Out:
# (4,)

# %%
array123 = np.array([[1,2,3,4]])
array123
# Out:
# array([[1, 2, 3, 4]])

# %%
array123.shape
# Out:
# (1, 4)

# %%
array12 * 2
# Out:
# array([2, 4, 6, 8])

# %%
array4 = array12 * 2 - 4
array4
# Out:
# array([-2,  0,  2,  4])

# %%
array4 - array12
# Out:
# array([-3, -2, -1,  0])

# %%
[array4 > 1]
# Out:
# [array([False, False,  True,  True])]

# %%
array4[array4 > 1]
# Out:
# array([2, 4])

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Usuario\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.linspace(-5,5,40)   #creamos el array de -5 a 5 con 40 elementos (n de pasos)

# %%
x
# Out:
# array([-5.        , -4.74358974, -4.48717949, -4.23076923, -3.97435897,
#        -3.71794872, -3.46153846, -3.20512821, -2.94871795, -2.69230769,
#        -2.43589744, -2.17948718, -1.92307692, -1.66666667, -1.41025641,
#        -1.15384615, -0.8974359 , -0.64102564, -0.38461538, -0.12820513,
#         0.12820513,  0.38461538,  0.64102564,  0.8974359 ,  1.15384615,
#         1.41025641,  1.66666667,  1.92307692,  2.17948718,  2.43589744,
#         2.69230769,  2.94871795,  3.20512821,  3.46153846,  3.71794872,
#         3.97435897,  4.23076923,  4.48717949,  4.74358974,  5.        ])

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.95892427,  0.9995133 ,  0.97474735,  0.88624579,  0.73979547,
#         0.54497229,  0.31451512,  0.06349281, -0.19168108, -0.43432157,
#        -0.64856316, -0.82039728, -0.93858826, -0.99540796, -0.98714112,
#        -0.91432829, -0.78173046, -0.59801779, -0.37520265, -0.12785421,
#         0.12785421,  0.37520265,  0.59801779,  0.78173046,  0.91432829,
#         0.98714112,  0.99540796,  0.93858826,  0.82039728,  0.64856316,
#         0.43432157,  0.19168108, -0.06349281, -0.31451512, -0.54497229,
#        -0.73979547, -0.88624579, -0.97474735, -0.9995133 , -0.95892427])

# %%
plt.plot(y)

# %%
plt.xlabel("eje x")
plt.ylabel("eje y")
plt.title("Seno de -5 a 5")

plt.plot(x,y,linestyle='dashdot',marker='o')   #corregimos con "x" en este caso para q el eje x vaya desde -5 a 5

# %%
# Generar datos aleatorios
labels = ['A', 'B', 'C', 'D']
values = np.random.randint(low=1, high=1000, size=4)

# Crear el gráfico
plt.bar(labels, values, color="olivedrab")
plt.title("Gráfico de barras")
plt.xlabel("Categorías")
plt.ylabel("Valores")
plt.show()

# %%
f = np.random.randn(100)
g = np.random.randn(100)

plt.scatter(f, g)

plt.title("Gráfico de dispersión")
plt.xlabel("Valores f")
plt.ylabel("Valores g")
plt.show()

# %%
data = np.random.randn(100)

plt.hist(data, bins=5, color = "Red")

plt.title("Histograma")
plt.xlabel("Valores")
plt.ylabel("Frecuencia")
plt.show()

# %%
#cuando tenemos diferentes plots en una figura, los cambios de titulo, etc se realizan con set_:


fig, ax = plt.subplots(2, 2, figsize=(13, 8)) # 2 filas, 2 columnas
ax[0, 0].plot([1, 2, 3, 4], [1, 4, 2, 3]) # Dibuja en el primer subplot
ax[0, 1].bar([1, 2, 3, 4], [1, 4, 2, 3]) # Dibuja en el segundo subplot
ax[0, 1].set_title('Titulo del Bar')
ax[1, 0].scatter([1, 2, 3, 4], [1, 4, 2, 3]) # Dibuja en el tercer subplot
ax[1, 0].set_ylabel('Eje Y de la nube de puntos')
ax[1, 1].pie([10, 20, 30, 40]) # Dibuja en el cuarto subplot
# Out:
# ([<matplotlib.patches.Wedge at 0x1a1eab3a560>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, ''),
#   Text(0.33991867422268784, 1.0461621742897658, ''),
#   Text(-1.0461621902025062, 0.3399186252483017, ''),
#   Text(0.3399188211458418, -1.0461621265515308, '')])
